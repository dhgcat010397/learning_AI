# %% [markdown]
# ## Xử lý Local

# %% [markdown]
# Xử lý local (cục bộ) là xử lý tại 1 vùng xung quanh 1 điểm ảnh nào đó.

# %% [markdown]
# #### Phép tích chập (Convolution)

# %% [markdown]
# #### Phép tương quan chéo (Cross-correlation)
