# %%
Y_test = [0, 1, 1, 0]
Y_pred = [0, 1, 0, 0]
Y_pred_prob = [0.1, 0.9, 0.4, 0.2]  # probabilities for positive class

# %%
from sklearn import metrics

print("Accuracy:", metrics.accuracy_score(Y_test, Y_pred))
print("Precision:", metrics.precision_score(Y_test, Y_pred))
print("Recall:", metrics.recall_score(Y_test, Y_pred))
print("F1 Score:", metrics.f1_score(Y_test, Y_pred))
print("ROC-AUC:", metrics.roc_auc_score(Y_test, Y_pred_prob))
# Out:
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.5
# F1 Score: 0.6666666666666666
# ROC-AUC: 1.0

# %%
from sklearn.metrics import (
    accuracy_score as ACC,
    precision_score as PRE,
    recall_score as REC,
    f1_score as F1,
    roc_auc_score as ROC_AUC,
)

print("Accuracy:", ACC(Y_test, Y_pred))
print("Precision:", PRE(Y_test, Y_pred))
print("Recall:", REC(Y_test, Y_pred))
print("F1 Score:", F1(Y_test, Y_pred))
print("ROC-AUC:", ROC_AUC(Y_test, Y_pred_prob))
# Out:
# Accuracy: 0.75
# Precision: 1.0
# Recall: 0.5
# F1 Score: 0.6666666666666666
# ROC-AUC: 1.0
